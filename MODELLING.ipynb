# %%
import pandas as pd

# %%
# Data Loading
file_path = "2018.csv"
df_2018 = pd.read_csv(file_path)
df_2018.head()
# Out:
#       FL_DATE OP_CARRIER  ...  LATE_AIRCRAFT_DELAY Unnamed: 27
# 0  2018-01-01         UA  ...                  NaN         NaN
# 1  2018-01-01         UA  ...                  NaN         NaN
# 2  2018-01-01         UA  ...                  NaN         NaN
# 3  2018-01-01         UA  ...                  NaN         NaN
# 4  2018-01-01         UA  ...                  NaN         NaN
#
# [5 rows x 28 columns]

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196257 entries, 0 to 196256
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FL_DATE              196257 non-null  object
#  1   OP_CARRIER           196257 non-null  object
#  2   OP_CARRIER_FL_NUM    196257 non-null  int64
#  3   ORIGIN               196257 non-null  object
#  4   DEST                 196257 non-null  object
#  5   CRS_DEP_TIME         196257 non-null  int64
#  6   DEP_TIME             187582 non-null  float64
#  7   DEP_DELAY            187360 non-null  float64
#  8   TAXI_OUT             187479 non-null  float64
#  9   WHEELS_OFF           187479 non-null  float64
#  10  WHEELS_ON            187265 non-null  float64
#  11  TAXI_IN              187265 non-null  float64
#  12  CRS_ARR_TIME         196257 non-null  int64
#  13  ARR_TIME             187265 non-null  float64
# ...

# %%
df_2018_test = df_2018
df_2018_test.dropna() 
df_2018_test.isnull().count()
# Out:
# FL_DATE                196257
# OP_CARRIER             196257
# OP_CARRIER_FL_NUM      196257
# ORIGIN                 196257
# DEST                   196257
# CRS_DEP_TIME           196257
# DEP_TIME               196257
# DEP_DELAY              196257
# TAXI_OUT               196257
# WHEELS_OFF             196257
# WHEELS_ON              196257
# TAXI_IN                196257
# CRS_ARR_TIME           196257
# ARR_TIME               196257
# ARR_DELAY              196257
# CANCELLED              196257
# CANCELLATION_CODE      196257
# DIVERTED               196257
# CRS_ELAPSED_TIME       196257
# ACTUAL_ELAPSED_TIME    196257
# AIR_TIME               196257
# DISTANCE               196257
# CARRIER_DELAY          196257
# WEATHER_DELAY          196257
# NAS_DELAY              196257
# SECURITY_DELAY         196257
# LATE_AIRCRAFT_DELAY    196257
# Unnamed: 27            196257
# dtype: int64

# %%
df_2018.shape
# Out:
# (196257, 28)

# %%
df_2018.isnull().sum()
# Out:
# FL_DATE                     0
# OP_CARRIER                  0
# OP_CARRIER_FL_NUM           0
# ORIGIN                      0
# DEST                        0
# CRS_DEP_TIME                0
# DEP_TIME                 8675
# DEP_DELAY                8897
# TAXI_OUT                 8778
# WHEELS_OFF               8778
# WHEELS_ON                8992
# TAXI_IN                  8992
# CRS_ARR_TIME                0
# ARR_TIME                 8992
# ARR_DELAY                9463
# CANCELLED                   0
# CANCELLATION_CODE      187422
# DIVERTED                    0
# CRS_ELAPSED_TIME            0
# ACTUAL_ELAPSED_TIME      9392
# AIR_TIME                 9392
# DISTANCE                    0
# CARRIER_DELAY          154518
# WEATHER_DELAY          154518
# NAS_DELAY              154518
# SECURITY_DELAY         154518
# LATE_AIRCRAFT_DELAY    154518
# Unnamed: 27            196257
# dtype: int64

# %%
df_2018['NAS_DELAY'] = df_2018['NAS_DELAY'].fillna(0)
df_2018['LATE_AIRCRAFT_DELAY'] = df_2018['LATE_AIRCRAFT_DELAY'].fillna(0)
df_2018['SECURITY_DELAY'] = df_2018['SECURITY_DELAY'].fillna(0)
df_2018['LATE_AIRCRAFT_DELAY'] = df_2018['LATE_AIRCRAFT_DELAY'].fillna(0)
df_2018['WEATHER_DELAY'] = df_2018['WEATHER_DELAY'].fillna(0)
df_2018['CARRIER_DELAY'] = df_2018['CARRIER_DELAY'].fillna(0)

# %%
df_2018 = df_2018.drop(columns=["Unnamed: 27"])
df_2018.head()
# Out:
#       FL_DATE OP_CARRIER  ...  SECURITY_DELAY LATE_AIRCRAFT_DELAY
# 0  2018-01-01         UA  ...             0.0                 0.0
# 1  2018-01-01         UA  ...             0.0                 0.0
# 2  2018-01-01         UA  ...             0.0                 0.0
# 3  2018-01-01         UA  ...             0.0                 0.0
# 4  2018-01-01         UA  ...             0.0                 0.0
#
# [5 rows x 27 columns]

# %%
df_2018.isnull().sum()
# Out:
# FL_DATE                     0
# OP_CARRIER                  0
# OP_CARRIER_FL_NUM           0
# ORIGIN                      0
# DEST                        0
# CRS_DEP_TIME                0
# DEP_TIME                 8675
# DEP_DELAY                8897
# TAXI_OUT                 8778
# WHEELS_OFF               8778
# WHEELS_ON                8992
# TAXI_IN                  8992
# CRS_ARR_TIME                0
# ARR_TIME                 8992
# ARR_DELAY                9463
# CANCELLED                   0
# CANCELLATION_CODE      187422
# DIVERTED                    0
# CRS_ELAPSED_TIME            0
# ACTUAL_ELAPSED_TIME      9392
# AIR_TIME                 9392
# DISTANCE                    0
# CARRIER_DELAY               0
# WEATHER_DELAY               0
# NAS_DELAY                   0
# SECURITY_DELAY              0
# LATE_AIRCRAFT_DELAY         0
# dtype: int64

# %%
# group by CANCELLATION_REASON to see the ration
df_2018['CANCELLATION_CODE'].value_counts()
# Out:
# B    6629
# A    1230
# C     976
# Name: CANCELLATION_CODE, dtype: int64

# %%
df_2018.OP_CARRIER.unique()
# Out:
# array(['UA', 'AS', '9E', 'B6', 'EV', 'F9', 'G4', 'HA', 'MQ', 'NK', 'OH',
#        'OO', 'VX', 'WN', 'YV', 'YX', 'AA', 'DL'], dtype=object)

# %%
df_2018.OP_CARRIER.nunique()
# Out:
# 18

# %%
df_2018.OP_CARRIER.value_counts()
# Out:
# WN    36517
# AA    24494
# DL    22346
# OO    22203
# UA    17146
# B6     8985
# MQ     8226
# YX     8164
# OH     7975
# EV     7323
# 9E     6327
# YV     5571
# AS     5498
# NK     5027
# F9     3400
# G4     2598
# HA     2350
# VX     2107
# Name: OP_CARRIER, dtype: int64

# %%
df_2018['OP_CARRIER'].replace({
    'UA':'United Airlines',
    'AS':'Alaska Airlines',
    '9E':'Endeavor Air',
    'B6':'JetBlue Airways',
    'EV':'ExpressJet',
    'F9':'Frontier Airlines',
    'G4':'Allegiant Air',
    'HA':'Hawaiian Airlines',
    'MQ':'Envoy Air',
    'NK':'Spirit Airlines',
    'OH':'PSA Airlines',
    'OO':'SkyWest Airlines',
    'VX':'Virgin America',
    'WN':'Southwest Airlines',
    'YV':'Mesa Airline',
    'YX':'Republic Airways',
    'AA':'American Airlines',
    'DL':'Delta Airlines'
}, inplace=True)

# %%
df_2018.OP_CARRIER.unique()
# Out:
# array(['United Airlines', 'Alaska Airlines', 'Endeavor Air',
#        'JetBlue Airways', 'ExpressJet', 'Frontier Airlines',
#        'Allegiant Air', 'Hawaiian Airlines', 'Envoy Air',
#        'Spirit Airlines', 'PSA Airlines', 'SkyWest Airlines',
#        'Virgin America', 'Southwest Airlines', 'Mesa Airline',
#        'Republic Airways', 'American Airlines', 'Delta Airlines'],
#       dtype=object)

# %%
df_2018.CANCELLED.nunique()
# Out:
# 2

# %%
df_2018.CANCELLED.value_counts()
# Out:
# 0.0    187422
# 1.0      8835
# Name: CANCELLED, dtype: int64

# %%
df1 = df_2018[(df_2018['CANCELLED'] == 0)]
df1.head(10)
# Out:
#       FL_DATE       OP_CARRIER  ...  SECURITY_DELAY LATE_AIRCRAFT_DELAY
# 0  2018-01-01  United Airlines  ...             0.0                 0.0
# 1  2018-01-01  United Airlines  ...             0.0                 0.0
# 2  2018-01-01  United Airlines  ...             0.0                 0.0
# 3  2018-01-01  United Airlines  ...             0.0                 0.0
# 4  2018-01-01  United Airlines  ...             0.0                 0.0
# 5  2018-01-01  United Airlines  ...             0.0                 0.0
# 6  2018-01-01  United Airlines  ...             0.0                 0.0
# 7  2018-01-01  United Airlines  ...             0.0                 0.0
# 8  2018-01-01  United Airlines  ...             0.0                 0.0
# 9  2018-01-01  United Airlines  ...             0.0                 0.0
#
# [10 rows x 27 columns]

# %%
df1.shape
# Out:
# (187422, 27)

# %%
df1.CANCELLATION_CODE.nunique()
# Out:
# 0

# %%
df1 = df1.drop(['CANCELLED'], axis = 1)

# %%
df1=df1.drop(['OP_CARRIER_FL_NUM'], axis = 1)

# %%
df1=df1.drop(['TAXI_OUT'], axis = 1)

# %%
df1=df1.drop(['WHEELS_OFF'], axis = 1)

# %%
df1=df1.drop(['WHEELS_ON'], axis = 1)

# %%
df1=df1.drop(['TAXI_IN'], axis = 1)

# %%
df1.shape
# Out:
# (187422, 21)

# %%
airport = pd.read_csv('airport.csv')
airport.head()
# Out:
#        id ident           type  ... home_link  wikipedia_link  keywords
# 0    6523   00A       heliport  ...       NaN             NaN       NaN
# 1  323361  00AA  small_airport  ...       NaN             NaN       NaN
# 2    6524  00AK  small_airport  ...       NaN             NaN       NaN
# 3    6525  00AL  small_airport  ...       NaN             NaN       NaN
# 4    6526  00AR         closed  ...       NaN             NaN      00AR
#
# [5 rows x 18 columns]

# %%
airport.shape
# Out:
# (70174, 18)

# %%
airport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70174 entries, 0 to 70173
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 70174 non-null  int64
#  1   ident              70174 non-null  object
#  2   type               70174 non-null  object
#  3   name               70174 non-null  object
#  4   latitude_deg       70174 non-null  float64
#  5   longitude_deg      70174 non-null  float64
#  6   elevation_ft       56986 non-null  float64
#  7   continent          35545 non-null  object
#  8   iso_country        69917 non-null  object
#  9   iso_region         70174 non-null  object
#  10  municipality       64833 non-null  object
#  11  scheduled_service  70174 non-null  object
#  12  gps_code           42694 non-null  object
#  13  iata_code          9228 non-null   object
#  14  local_code         32431 non-null  object
#  15  home_link          3367 non-null   object
# ...

# %%
airport.iata_code.nunique()
# Out:
# 9131

# %%
df1.ORIGIN.nunique()
# Out:
# 333

# %%
df1.DEST.nunique()
# Out:
# 333

# %%
airport_IATA_CODE = list(airport['iata_code'])

# %%
df1_ORIGIN = list(df1['ORIGIN'])

# %%
df1_Dest =list(df1['DEST'])

# %%
merged_df = df1.merge(airport, how='inner', left_on=['ORIGIN'], right_on=['iata_code'])
merged_df.head()
# Out:
#       FL_DATE  ...                       keywords
# 0  2018-01-01  ...  Manhattan, New York City, NYC
# 1  2018-01-01  ...  Manhattan, New York City, NYC
# 2  2018-01-01  ...  Manhattan, New York City, NYC
# 3  2018-01-01  ...  Manhattan, New York City, NYC
# 4  2018-01-01  ...  Manhattan, New York City, NYC
#
# [5 rows x 39 columns]

# %%
merged_df = merged_df.drop(columns=['id' ,'ident','type','elevation_ft','continent', 'iso_country' ,'scheduled_service','gps_code' ,'local_code',	'home_link'	,'wikipedia_link','keywords', 'iso_region','iata_code'	])

# %%
merged_df.shape
# Out:
# (187329, 25)

# %%
merged_df = merged_df.rename(columns={'name':'Org_Airport','latitude_deg':'Org_latitude','longitude_deg': 'Org_longitude'   , 'municipality':'Origin_city'})

# %%
merged_df.head()
# Out:
#       FL_DATE       OP_CARRIER ORIGIN  ... Org_latitude  Org_longitude  Origin_city
# 0  2018-01-01  United Airlines    EWR  ...    40.692501     -74.168701     New York
# 1  2018-01-01  United Airlines    EWR  ...    40.692501     -74.168701     New York
# 2  2018-01-01  United Airlines    EWR  ...    40.692501     -74.168701     New York
# 3  2018-01-01  United Airlines    EWR  ...    40.692501     -74.168701     New York
# 4  2018-01-01  United Airlines    EWR  ...    40.692501     -74.168701     New York
#
# [5 rows x 25 columns]

# %%
merged_df = merged_df.merge(airport, how='inner', left_on=['DEST'], right_on=['iata_code'])
merged_df.head()
# Out:
#       FL_DATE  ...   keywords
# 0  2018-01-01  ...  DVX, KVDX
# 1  2018-01-01  ...  DVX, KVDX
# 2  2018-01-01  ...  DVX, KVDX
# 3  2018-01-01  ...  DVX, KVDX
# 4  2018-01-01  ...  DVX, KVDX
#
# [5 rows x 43 columns]

# %%
merged_df = merged_df.drop(columns=['id' ,'ident','type','elevation_ft','continent', 'iso_country' ,'scheduled_service','gps_code' ,'local_code',	'home_link'	,'wikipedia_link','keywords', 'iso_region','iata_code'	])

# %%
merged_df = merged_df.rename(columns={'name':'Dest_Airport','latitude_deg':'Dest_latitude','longitude_deg': 'Dest_longitude'   , 'municipality':'Dest_city'})

# %%
merged_df.head()
# Out:
#       FL_DATE       OP_CARRIER ORIGIN  ... Dest_latitude  Dest_longitude  Dest_city
# 0  2018-01-01  United Airlines    EWR  ...     39.861698     -104.672996     Denver
# 1  2018-01-01  United Airlines    EWR  ...     39.861698     -104.672996     Denver
# 2  2018-01-01  United Airlines    EWR  ...     39.861698     -104.672996     Denver
# 3  2018-01-01  United Airlines    EWR  ...     39.861698     -104.672996     Denver
# 4  2018-01-01  United Airlines    EWR  ...     39.861698     -104.672996     Denver
#
# [5 rows x 29 columns]

# %%
# differences between df1_ORIGIN and airport_IATA_CODE
#difference_1 = [item for item in df1_ORIGIN if item not in airport_IATA_CODE]
#difference_1

# %%
# differences between df1_ORIGIN and airport_IATA_CODE
#difference_2 = [item for item in df1_Dest if item not in airport_IATA_CODE]
#difference_2

# %%
#df1.to_csv('2018_clean1.csv', index=False)

# %%
import datetime, warnings, scipy 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.combine import SMOTEENN
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Lasso,LinearRegression,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,BaggingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
merged_df['FL_DATE']  = pd.to_datetime(merged_df.FL_DATE)

# %%
merged_df.dtypes
# Out:
# FL_DATE                datetime64[ns]
# OP_CARRIER                     object
# ORIGIN                         object
# DEST                           object
# CRS_DEP_TIME                    int64
# DEP_TIME                      float64
# DEP_DELAY                     float64
# CRS_ARR_TIME                    int64
# ARR_TIME                      float64
# ARR_DELAY                     float64
# CANCELLATION_CODE              object
# DIVERTED                      float64
# CRS_ELAPSED_TIME              float64
# ACTUAL_ELAPSED_TIME           float64
# AIR_TIME                      float64
# DISTANCE                      float64
# CARRIER_DELAY                 float64
# WEATHER_DELAY                 float64
# NAS_DELAY                     float64
# SECURITY_DELAY                float64
# LATE_AIRCRAFT_DELAY           float64
# Org_Airport                    object
# Org_latitude                  float64
# Org_longitude                 float64
# Origin_city                    object
# ...

# %%
merged_df['year'] = pd.DatetimeIndex(merged_df['FL_DATE']).year
merged_df['month'] = pd.DatetimeIndex(merged_df['FL_DATE']).month
merged_df['Day'] = pd.DatetimeIndex(merged_df['FL_DATE']).day
merged_df
# Out:
#           FL_DATE        OP_CARRIER ORIGIN DEST  ...    Dest_city  year  month  Day
# 0      2018-01-01   United Airlines    EWR  DEN  ...       Denver  2018      1    1
# 1      2018-01-01   United Airlines    EWR  DEN  ...       Denver  2018      1    1
# 2      2018-01-01   United Airlines    EWR  DEN  ...       Denver  2018      1    1
# 3      2018-01-01   United Airlines    EWR  DEN  ...       Denver  2018      1    1
# 4      2018-01-01   United Airlines    EWR  DEN  ...       Denver  2018      1    1
# ...           ...               ...    ...  ...  ...          ...   ...    ...  ...
# 187231 2018-01-08  SkyWest Airlines    JMS  DVL  ...  Devils Lake  2018      1    8
# 187232 2018-01-08  SkyWest Airlines    JMS  DVL  ...  Devils Lake  2018      1    8
# 187233 2018-01-10  SkyWest Airlines    JMS  DVL  ...  Devils Lake  2018      1   10
# 187234 2018-01-11  SkyWest Airlines    JMS  DVL  ...  Devils Lake  2018      1   11
# ...

# %%
Las = Lasso()
LinR = LinearRegression()
Rid = Ridge()
Rfc = RandomForestRegressor(random_state=2)
Dtc = DecisionTreeRegressor(random_state = 2)
Boost_Lin = AdaBoostRegressor(base_estimator=LinR,random_state=2)
Boost_las = AdaBoostRegressor(base_estimator=Las,random_state=2)
Boost_rid = AdaBoostRegressor(base_estimator=Rid,random_state=2)
Bg_Lin = BaggingRegressor(base_estimator=LinR,random_state=2)
Bg_las = BaggingRegressor(base_estimator=Las,random_state=2)
Bg_rid = BaggingRegressor(base_estimator=Rid,random_state=2)

# %%
merged_df.columns
# Out:
# Index(['FL_DATE', 'OP_CARRIER', 'ORIGIN', 'DEST', 'CRS_DEP_TIME', 'DEP_TIME',
#        'DEP_DELAY', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
#        'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
#        'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY',
#        'Org_Airport', 'Org_latitude', 'Org_longitude', 'Origin_city',
#        'Dest_Airport', 'Dest_latitude', 'Dest_longitude', 'Dest_city', 'year',
#        'month', 'Day'],
#       dtype='object')

# %%
le = LabelEncoder()

# %%
# Label encoding features to change categorical variables into numerical one
merged_df['OP_CARRIER'] = le.fit_transform(merged_df['OP_CARRIER'])
merged_df['Org_Airport'] = le.fit_transform(merged_df['Org_Airport'])
merged_df['Dest_Airport']= le.fit_transform(merged_df['Dest_Airport'])
merged_df['Day'] = le.fit_transform(merged_df['Day'])

# %%
Flights1 = merged_df.drop(['FL_DATE', 'ORIGIN', 'DEST',
       'CANCELLATION_CODE', 'DIVERTED', 'CRS_ELAPSED_TIME',
       'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE', 'CARRIER_DELAY',
       'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY', 
       'Org_latitude', 'Org_longitude', 'Origin_city', 'Dest_latitude', 'Dest_longitude', 'Dest_city', 'year',
       'month'], axis = 1)

# %%
Flights1.isnull().sum()
Flights1.columns
# Out:
# Index(['OP_CARRIER', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'CRS_ARR_TIME',
#        'ARR_TIME', 'ARR_DELAY', 'Org_Airport', 'Dest_Airport', 'Day'],
#       dtype='object')

# %%
Flights1 = Flights1.dropna(subset = ['OP_CARRIER', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'CRS_ARR_TIME',
       'ARR_TIME', 'ARR_DELAY', 'Org_Airport', 'Dest_Airport', 'Day'])

# %%
Flights1.isnull().sum()
# Out:
# OP_CARRIER      0
# CRS_DEP_TIME    0
# DEP_TIME        0
# DEP_DELAY       0
# CRS_ARR_TIME    0
# ARR_TIME        0
# ARR_DELAY       0
# Org_Airport     0
# Dest_Airport    0
# Day             0
# dtype: int64

# %%
Flights1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186399 entries, 0 to 187235
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   OP_CARRIER    186399 non-null  int64
#  1   CRS_DEP_TIME  186399 non-null  int64
#  2   DEP_TIME      186399 non-null  float64
#  3   DEP_DELAY     186399 non-null  float64
#  4   CRS_ARR_TIME  186399 non-null  int64
#  5   ARR_TIME      186399 non-null  float64
#  6   ARR_DELAY     186399 non-null  float64
#  7   Org_Airport   186399 non-null  int64
#  8   Dest_Airport  186399 non-null  int64
#  9   Day           186399 non-null  int64
# dtypes: float64(4), int64(6)
# memory usage: 15.6 MB

# %%
X = Flights1.drop('DEP_DELAY',axis = 1)
X.shape
# Out:
# (186399, 9)

# %%
y = Flights1['DEP_DELAY']
y.head()
# Out:
# 0     -5.0
# 1    161.0
# 2     -1.0
# 3     11.0
# 4     -1.0
# Name: DEP_DELAY, dtype: float64

# %%
# Splitting into train and test data set
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state = 2)

# %%
sc1=StandardScaler()
X_train_sc=sc1.fit_transform(X_train)
X_test_sc=sc1.transform(X_test)

# %% [markdown]
# MODEL FITTING AND RESULTS

# %%
for model, name in zip([Las,LinR,Rid,Dtc,Rfc,Boost_Lin,Boost_las,Boost_rid,Bg_Lin,Bg_las,Bg_rid], 
     ['Lasso','Linear Regression','Ridge','Random forest Regressor','Decision Tree Regressor','Boosted Linear',
      'Boosted Lasso','Boosted Ridge','Bagged Linear','Bagged Lasso','Bagged Ridge']):
    model1 = model.fit(X_train_sc,y_train)
    Y_predict=model1.predict(X_test_sc)
    print(name)
    print('Mean Absolute Error:', mean_absolute_error(y_test, Y_predict))  
    print('Mean Squared Error:', mean_squared_error(y_test, Y_predict))  
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, Y_predict)))
    print('R2 : ',r2_score(y_test, Y_predict))
    print()
# Out:
# Lasso
# Mean Absolute Error: 9.413422774728788
# Mean Squared Error: 175.75767030658392
# Root Mean Squared Error: 13.257362871498385
# R2 :  0.9365054103789411
#
# Linear Regression
# Mean Absolute Error: 9.39418924375306
# Mean Squared Error: 173.16069367352557
# Root Mean Squared Error: 13.159053676975619
# R2 :  0.9374435996783548
#
# Ridge
# Mean Absolute Error: 9.394173201911391
# Mean Squared Error: 173.1607884773578
# Root Mean Squared Error: 13.15905727920347
# R2 :  0.9374435654293208
#
# Random forest Regressor
# Mean Absolute Error: 6.884567238912733
# Mean Squared Error: 126.9940808297568
# Root Mean Squared Error: 11.269165045812258
# R2 :  0.9541218483806512
#
# Decision Tree Regressor
# Mean Absolute Error: 4.930464055793992
# Mean Squared Error: 62.61768915057225
# Root Mean Squared Error: 7.913133965160216
# R2 :  0.977378600497496
#
# Boosted Linear
# Mean Absolute Error: 9.733890864188487
# Mean Squared Error: 180.35110247211307
# ...

# %% [markdown]
# MODEL ANALYSIS

# %%
for model, name in zip([Las,LinR,Rid,Dtc,Rfc,Boost_Lin,Boost_las,Boost_rid,Bg_Lin,Bg_las,Bg_rid], 
     ['Lasso','Linear Regression','Ridge','Random forest Regressor','Decision Tree Regressor','Boosted Linear',
      'Boosted Lasso','Boosted Ridge','Bagged Linear','Bagged Lasso','Bagged Ridge']):
    model1 = model.fit(X_train_sc,y_train)
    Y_predict=model1.predict(X_test_sc)
    print(name)
    plt.scatter(y_test, Y_predict)
    plt.title("Model Analysis")
    plt.xlabel("Truth")
    plt.ylabel("Prediction")
    plt.show()
# Out:
# Lasso
# Linear Regression
# Ridge
# Random forest Regressor
